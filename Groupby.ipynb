# %%
import pandas as pd
df=pd.read_csv('nba.csv')
df.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
df2=df.groupby(['Team']).agg({'Number':['sum','count']})
df2.head()
# Out:
#                   Number
#                      sum count
# Team
# Atlanta Hawks      285.0    15
# Boston Celtics     478.0    15
# Brooklyn Nets      274.0    15
# Charlotte Hornets  257.0    15
# Chicago Bulls      288.0    15

# %%
#df2.head()
df3=df2.droplevel(1,axis=1).reset_index().rename(columns={'sum':'Num_Sum','count':'Num_count'}).copy()
df3.head()
# Out:
#                 Team  Number  Number
# 0      Atlanta Hawks   285.0      15
# 1     Boston Celtics   478.0      15
# 2      Brooklyn Nets   274.0      15
# 3  Charlotte Hornets   257.0      15
# 4      Chicago Bulls   288.0      15

# %%
#df2
df3=df2.droplevel(0,axis=1).reset_index().rename(columns={"sum":"Num_sum","count":"Num_count"})
df3.head()
df4=df3.set_index("Team")
df4.head()
# Out:
#                    Num_sum  Num_count
# Team
# Atlanta Hawks        285.0         15
# Boston Celtics       478.0         15
# Brooklyn Nets        274.0         15
# Charlotte Hornets    257.0         15
# Chicago Bulls        288.0         15

# %%
df5=df4.reset_index()

df5.query('Num_sum==[285,478] and Num_count==15').index

#df5.drop(df5[(df5['Num_sum'].isin([285,478])) & (df5['Num_count'].isin([15]))].index,inplace=True)
#

#df5
# Out:
# Int64Index([0, 1], dtype='int64')

# %%
df = pd.DataFrame([[1, 1.5]], columns=['int', 'float'])
row = next(df.iterrows())[1]

df3=pd.DataFrame(row)
df3
# Out:
#          0
# int    1.0
# float  1.5

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.randn(10,4),index=pd.date_range('1/1/2000',
   periods=10), columns=list('ABCD'))

df.plot()
# Out:
# <AxesSubplot:>

# %%
df2=df.groupby(['Team']).agg({'Weight':'sum','Salary':'sum','Name':lambda x :x.nunique()})
df2.reset_index().head()
# Out:
#                 Team  Weight      Salary  Name
# 0      Atlanta Hawks  3319.0  72902950.0    15
# 1     Boston Celtics  3292.0  58541068.0    15
# 2      Brooklyn Nets  3234.0  52528475.0    15
# 3  Charlotte Hornets  3306.0  78340920.0    15
# 4      Chicago Bulls  3284.0  86783378.0    15

# %%
df2=df.groupby("Team")['Salary'].sum()
#df2.sort_values()


df2.reset_index().sort_values(by=['Salary'],ascending=False)
# Out:
#                       Team       Salary
# 5      Cleveland Cavaliers  106988689.0
# 12    Los Angeles Clippers   94854640.0
# 20   Oklahoma City Thunder   93765298.0
# 9    Golden State Warriors   88868997.0
# 4            Chicago Bulls   86783378.0
# 26       San Antonio Spurs   84442733.0
# 18    New Orleans Pelicans   82750774.0
# 15              Miami Heat   82515673.0
# 3        Charlotte Hornets   78340920.0
# 14       Memphis Grizzlies   76550880.0
# 29      Washington Wizards   76328636.0
# 10         Houston Rockets   75283021.0
# 19         New York Knicks   73303898.0
# 0            Atlanta Hawks   72902950.0
# 13      Los Angeles Lakers   71770431.0
# 25        Sacramento Kings   71683666.0
# 6         Dallas Mavericks   71198732.0
# 27         Toronto Raptors   71117611.0
# 16         Milwaukee Bucks   69603517.0
# 8          Detroit Pistons   67168263.0
# 11          Indiana Pacers   66751826.0
# 23            Phoenix Suns   63445135.0
# ...

# %%
import pandas as pd
df=pd.Series([1,2,3,4,5],index=[0,1,2,3,4])
df.head()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
a=[1,2,3,4,5]

df=pd.DataFrame(list(map(lambda x:x,a)))


df
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
type(df)
# Out:
# list
